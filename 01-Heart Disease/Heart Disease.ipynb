# %% [markdown]
# # Heart Disease

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sbn

df = pd.read_csv("/home/student/ML/Heart Disease/76_attributes_heartdiseases.csv")
df.head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  V10  ...   V67  V68  V69  V70  V71  \
# 0   1   0  63   1  -9  -9  -9  -9   1  145  ...     1    1    1    1    1
# 1   2   0  67   1  -9  -9  -9  -9   4  160  ...     1    1    1    1    1
# 2   3   0  67   1  -9  -9  -9  -9   4  120  ...     2    2    1    1    1
# 3   4   0  37   1  -9  -9  -9  -9   3  130  ...     1    1    1    1    1
# 4   6   0  41   0  -9  -9  -9  -9   2  130  ...     1    1    1    1    1
#
#    V72  V73  V74  V75   V76
# 0    1    1   -9   -9  name
# 1    1    1   -9   -9  name
# 2    7    3   -9   -9  name
# 3    1    1   -9   -9  name
# 4    1    1   -9   -9  name
#
# [5 rows x 76 columns]

# %%
df.describe()
# Out:
#                V1     V2          V3          V4     V5     V6          V7  \
# count  282.000000  282.0  282.000000  282.000000  282.0  282.0  282.000000
# mean   151.517730    0.0   54.411348    0.677305   -9.0   -9.0   -9.095745
# std     87.131234    0.0    9.053083    0.468338    0.0    0.0    0.924970
# min      1.000000    0.0   29.000000    0.000000   -9.0   -9.0  -18.000000
# 25%     75.250000    0.0   48.000000    0.000000   -9.0   -9.0   -9.000000
# 50%    151.500000    0.0   55.000000    1.000000   -9.0   -9.0   -9.000000
# 75%    227.750000    0.0   61.000000    1.000000   -9.0   -9.0   -9.000000
# max    298.000000    0.0   77.000000    1.000000   -9.0   -9.0   -9.000000
#
#                V8          V9         V10  ...           V66         V67  \
# count  282.000000  282.000000  282.000000  ...    282.000000  282.000000
# mean    -8.868794    4.432624  130.269504  ...     -8.783688    1.173759
# ...

# %%
df.shape
# Out:
# (282, 76)

# %%
#print((df[['V5','V6','V7','V8','V13','V17','V30','V42','V45','V46','V47','V48','V49','V50','V51','V52','V53','V54','V62','V64','V66','V74','V75']] == -9).sum())
null_columns=df.columns[df.isnull().any()]
df[null_columns].isnull().sum()
# Out:
# Series([], dtype: float64)

# %%
import numpy as np
df[['V5','V6','V7','V8','V13','V17','V30','V42','V45','V46','V47','V48','V49','V50','V51','V52','V53','V54','V62','V64','V66','V74','V75']]=df[['V5','V6','V7','V8','V13','V17','V30','V42','V45','V46','V47','V48','V49','V50','V51','V52','V53','V54','V62','V64','V66','V74','V75']].replace(-9,np.NaN)

# %%
df.head()
# Out:
#    V1  V2  V3  V4  V5  V6  V7  V8  V9  V10  ...   V67  V68  V69  V70  V71  \
# 0   1   0  63   1 NaN NaN NaN NaN   1  145  ...     1    1    1    1    1
# 1   2   0  67   1 NaN NaN NaN NaN   4  160  ...     1    1    1    1    1
# 2   3   0  67   1 NaN NaN NaN NaN   4  120  ...     2    2    1    1    1
# 3   4   0  37   1 NaN NaN NaN NaN   3  130  ...     1    1    1    1    1
# 4   6   0  41   0 NaN NaN NaN NaN   2  130  ...     1    1    1    1    1
#
#    V72  V73  V74  V75   V76
# 0    1    1  NaN  NaN  name
# 1    1    1  NaN  NaN  name
# 2    7    3  NaN  NaN  name
# 3    1    1  NaN  NaN  name
# 4    1    1  NaN  NaN  name
#
# [5 rows x 76 columns]

# %%
df.dropna(axis='columns',inplace = True)

# %%
df
# Out:
#       V1  V2  V3  V4  V9  V10  V11  V12  V14  V15  ...   V63  V65  V67  V68  \
# 0      1   0  63   1   1  145    1  233   50   20  ...     1    1    1    1
# 1      2   0  67   1   4  160    1  286   40   40  ...     2    1    1    1
# 2      3   0  67   1   4  120    1  229   20   35  ...     1    1    2    2
# 3      4   0  37   1   3  130    0  250    0    0  ...     1    1    1    1
# 4      6   0  41   0   2  130    1  204    0    0  ...     1    1    1    1
# 5      7   0  56   1   2  120    1  236   20   20  ...     1    1    1    1
# 6      8   0  62   0   4  140    0  268    0    0  ...     1    2    2    1
# 7      9   0  57   0   4  120    1  354    0    0  ...     1    1    1    1
# 8     10   0  63   1   4  130    1  254    0    0  ...     1    1    2    1
# 9     11   0  53   1   4  140    0  203   20   25  ...     1    1    2    1
# 10    12   0  57   1   4  140    0  192   75   25  ...     1    1    1    1
# ...

# %%
df.loc[:,"V58"]
# Out:
# 0      0
# 1      2
# 2      1
# 3      0
# 4      0
# 5      0
# 6      3
# 7      0
# 8      2
# 9      1
# 10     0
# 11     0
# 12     2
# 13     0
# 14     0
# 15     0
# 16     1
# 17     0
# 18     0
# 19     0
# 20     0
# 21     0
# 22     1
# 23     3
# 24     4
# 25     0
# 26     0
# 27     0
# 28     0
# 29     3
#       ..
# 252    0
# 253    0
# 254    0
# 255    0
# 256    0
# 257    0
# 258    0
# 259    1
# 260    0
# 261    3
# 262    0
# 263    0
# 264    4
# 265    2
# 266    2
# 267    2
# 268    1
# 269    0
# 270    1
# 271    0
# 272    2
# 273    0
# 274    1
# 275    0
# 276    0
# 277    0
# 278    1
# 279    0
# 280    2
# 281    0
# Name: V58, Length: 282, dtype: int64

# %%
df.columns
# Out:
# Index(['V1', 'V2', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V15', 'V16',
#        'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
#        'V28', 'V29', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38',
#        'V39', 'V40', 'V41', 'V43', 'V44', 'V55', 'V56', 'V57', 'V58', 'V59',
#        'V60', 'V61', 'V63', 'V65', 'V67', 'V68', 'V69', 'V70', 'V71', 'V72',
#        'V73', 'V76'],
#       dtype='object')

# %%
import warnings
warnings.filterwarnings("ignore")
lst = ['V1', 'V2', 'V3', 'V4', 'V9', 'V10', 'V11', 'V12', 'V14', 'V15', 'V16',
       'V18', 'V19', 'V20', 'V21', 'V22', 'V23', 'V24', 'V25', 'V26', 'V27',
       'V28', 'V29', 'V31', 'V32', 'V33', 'V34', 'V35', 'V36', 'V37', 'V38',
       'V39', 'V40', 'V41', 'V43', 'V44', 'V55', 'V56', 'V57', 'V59',
       'V60', 'V61', 'V63', 'V65', 'V67', 'V68', 'V69', 'V70', 'V71', 'V72',
       'V73']
for i in lst:
    sbn.FacetGrid(df, hue="V58", size=5) \
       .map(sbn.distplot, i ) \
       .add_legend();
    plt.show()

# %%
df.to_csv("Cleaned_hd.csv")
